# %% [markdown]
# # Red Neuronal
#
# ---
#
# ### Daniela Jiménez Téllez - A01654798
# ### Lautaro Gabriel Coteja - A01571214
# ### Andrés Villareal González - A00833915
# ### Héctor Hibran Tapia Fernández - A01661114
#
# ---

# %%
import pandas as pd

# %%
df_entrenamiento = pd.read_csv("df_entrenamiento_final.csv")
df_prueba = pd.read_csv("df_prueba_final.csv")

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import pandas as pd
from sklearn.linear_model import LogisticRegression
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt


categorical_features = ['categoria_instalaciones', 'Flavor', 'sub_canal_comercial',
                        'ProductType', 'Returnability', 'Size', 'Container', 'MLSize']

X_train_full = df_entrenamiento[['categoria_instalaciones', 'pc_comercial_300m', 'Flavor', 'MLSize',
                                 'pc_negocios_300m', 'pc_turismo_300m', 'gasto_promedio_300m',
                                 'ingreso_promedio_300m', 'accesibilidad', 'sub_canal_comercial',
                                 'ProductType', 'Returnability', 'Size', 'Container',
                                 'success_ratio', 'success_ratio_flavor', 'success_ratio_mlsize',
                                 'success_ratio_container', 'pob_ab_300m', 'pob_cmas_300m',
                                 'pob_c_300m', 'pob_cmen_300m', 'pob_dmas_300m', 'pob_d_300m',
                                 'pob_e_300m']]
y_train_full = df_entrenamiento['successful']

X_test = df_prueba[['categoria_instalaciones', 'pc_comercial_300m', 'Flavor', 'MLSize',
                    'pc_negocios_300m', 'pc_turismo_300m', 'gasto_promedio_300m',
                    'ingreso_promedio_300m', 'accesibilidad', 'sub_canal_comercial',
                    'ProductType', 'Returnability', 'Size', 'Container',
                    'success_ratio', 'success_ratio_flavor', 'success_ratio_mlsize',
                    'success_ratio_container', 'pob_ab_300m', 'pob_cmas_300m',
                    'pob_c_300m', 'pob_cmen_300m', 'pob_dmas_300m', 'pob_d_300m',
                    'pob_e_300m']]
y_test = df_prueba['successful']

X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42)

X_combined = pd.concat([X_train, X_val, X_test], axis=0)
X_encoded = pd.get_dummies(X_combined, columns=categorical_features, drop_first=True)

X_train_encoded = X_encoded.iloc[:len(X_train), :]
X_val_encoded = X_encoded.iloc[len(X_train):len(X_train) + len(X_val), :]
X_test_encoded = X_encoded.iloc[len(X_train) + len(X_val):, :]

model = Sequential()

# Capa de entrada
model.add(Dense(64, input_dim=X_train_encoded.shape[1], activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Capas ocultas
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(16, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Capa de salida
model.add(Dense(1, activation='sigmoid'))  # Usamos sigmoide para una salida binaria

# Compilar el modelo
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(
    X_train_encoded,
    y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val_encoded, y_val),
    verbose=1
)

val_loss, val_accuracy = model.evaluate(X_val_encoded, y_val, verbose=0)
print(f'Precisión en el conjunto de validación: {val_accuracy:.2f}')

y_val_pred = (model.predict(X_val_encoded) > 0.5).astype(int)
print("\nReporte de clasificación en el conjunto de validación:")
print(classification_report(y_val, y_val_pred))
print("\nMatriz de confusión en el conjunto de validación:")
print(confusion_matrix(y_val, y_val_pred))

test_loss, test_accuracy = model.evaluate(X_test_encoded, y_test, verbose=0)
print(f'\nPrecisión en el conjunto de prueba: {test_accuracy:.2f}')

y_test_pred = (model.predict(X_test_encoded) > 0.5).astype(int)
print("\nReporte de clasificación en el conjunto de prueba:")
print(classification_report(y_test, y_test_pred))
print("\nMatriz de confusión en el conjunto de prueba:")
print(confusion_matrix(y_test, y_test_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.
50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7636 - loss: 0.5411 - val_accuracy: 0.7696 - val_loss: 0.5330
# Epoch 31/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7664 - loss: 0.5372 - val_accuracy: 0.7705 - val_loss: 0.5301
# Epoch 32/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7669 - loss: 0.5335 - val_accuracy: 0.7699 - val_loss: 0.5311
# Epoch 33/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7654 - loss: 0.5335 - val_accuracy: 0.7721 - val_loss: 0.5296
# Epoch 34/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7701 - loss: 0.5305 - val_accuracy: 0.7714 - val_loss: 0.5331
# Epoch 35/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7666 - loss: 0.5367 - val_accuracy: 0.7716 - val_loss: 0.5314
# Epoch 36/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7663 - loss: 0.5379 - val_accuracy: 0.7716 - val_loss: 0.5323
# Epoch 37/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7694 - loss: 0.5364 - val_accuracy: 0.7721 - val_loss: 0.5315
# Epoch 38/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7654 - loss: 0.5381 - val_accuracy: 0.7730 - val_loss: 0.5287
# Epoch 39/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7663 - loss: 0.5358 - val_accuracy: 0.7740 - val_loss: 0.5309
# Epoch 40/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7635 - loss: 0.5312 - val_accuracy: 0.7736 - val_loss: 0.5290
# Epoch 41/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7751 - loss: 0.5233 - val_accuracy: 0.7739 - val_loss: 0.5274
# Epoch 42/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7665 - loss: 0.5274 - val_accuracy: 0.7721 - val_loss: 0.5255
# Epoch 43/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7700 - loss: 0.5288 - val_accuracy: 0.7734 - val_loss: 0.5261
# Epoch 44/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7706 - loss: 0.5250 - val_accuracy: 0.7734 - val_loss: 0.4673
# Epoch 45/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7769 - loss: 0.5006 - val_accuracy: 0.7725 - val_loss: 0.5312
# Epoch 46/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7800 - loss: 0.4919 - val_accuracy: 0.7715 - val_loss: 0.5250
# Epoch 47/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7648 - loss: 0.5397 - val_accuracy: 0.7709 - val_loss: 0.5248
# Epoch 48/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7710 - loss: 0.5250 - val_accuracy: 0.7727 - val_loss: 0.5342
# Epoch 49/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7730 - loss: 0.5245 - val_accuracy: 0.7722 - val_loss: 0.4760
# Epoch 50/50
# 843/843 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7884 - loss: 0.4854 - val_accuracy: 0.7742 - val_loss: 0.4360
# Precisión en el conjunto de validación: 0.77
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Reporte de clasificación en el conjunto de validación:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87      5178
#            1       0.79      0.04      0.07      1566
#
#     accuracy                           0.77      6744
#    macro avg       0.78      0.52      0.47      6744
# weighted avg       0.78      0.77      0.69      6744
#
#
# Matriz de confusión en el conjunto de validación:
# [[5162   16]
#  [1507   59]]
#
# Precisión en el conjunto de prueba: 0.92
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Reporte de clasificación en el conjunto de prueba:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      6855
#            1       0.43      0.03      0.05       562
#
#     accuracy                           0.92      7417
#    macro avg       0.68      0.51      0.51      7417
# weighted avg       0.89      0.92      0.89      7417
#
#
# Matriz de confusión en el conjunto de prueba:
# [[6835   20]
#  [ 547   15]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
from sklearn.metrics import confusion_matrix

y_pred_prob = model.predict(X_test_encoded)
y_pred = (y_pred_prob >= 0.5).astype(int) 

cm = confusion_matrix(y_val, y_val_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['0', '1'], yticklabels=['0', '1'])
plt.title("Confusion Matrix")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()
# Out:
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
